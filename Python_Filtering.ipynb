# %%
# Pandas: it is a data cleaning and data analyzing tools used in python.
# import pandas as pd
# pip install <library name>
# !pip install <library name>
# Two types of data:
# Data Series: single dimesion value like array - one column, many rows.
# Data Frame: 2 dimesion array like the excel, sql, rows and columns.

# %%
import pandas as pd

# %%
# load the csv file: pd.read_csv(path) 
path = '/content/drive/MyDrive/data /weather.csv'
# path = 'weather.csv'
df = pd.read_csv(path)
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# head() show first 5 rows
# head(n) show first n rows.
# tail() show last 5 rows
# tail(n) show last n rows.
df.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
df.tail()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# ...

# %%
# entile information of dataframe like no. of columns, data type of each columns, no. of rows.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
# statistical information of all numerical columns.
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
# statistical information of data type object.
df.describe(include='object')
# Out:
#                        Formatted Date        Summary Precip Type  \
# count                           96453          96453       95936
# unique                          96429             27           2
# top     2010-08-02 00:00:00.000 +0200  Partly Cloudy        rain
# freq                                2          31733       85224
#
#                             Daily Summary
# count                               96453
# unique                                214
# top     Mostly cloudy throughout the day.
# freq                                20085

# %%
# Get the unique values of columns.
df['Precip Type'].unique()
# Out:
# array(['rain', 'snow', nan], dtype=object)

# %%
df['Daily Summary'].unique()
# Out:
# array(['Partly cloudy throughout the day.',
#        'Mostly cloudy throughout the day.', 'Foggy in the evening.',
#        'Foggy overnight and breezy in the morning.',
#        'Overcast throughout the day.', 'Partly cloudy until night.',
#        'Mostly cloudy until night.',
#        'Foggy starting overnight continuing until morning.',
#        'Foggy in the morning.', 'Partly cloudy until evening.',
#        'Partly cloudy starting in the morning.',
#        'Mostly cloudy starting overnight continuing until night.',
#        'Mostly cloudy until evening.',
#        'Partly cloudy starting in the morning continuing until evening.',
#        'Partly cloudy starting in the afternoon.',
#        'Partly cloudy starting overnight.',
#        'Partly cloudy until morning.',
#        'Partly cloudy starting overnight continuing until night.',
#        'Partly cloudy starting in the afternoon continuing until night.',
#        'Mostly cloudy starting overnight.',
# ...

# %%
# How many rows and cols
print('No. of Rows and Cols', df.shape)
print('No. of Rows:', len(df))
print('No. of Rows:', df.shape[0])
print('No. of Cols:', len(df.columns))
print('No. of Cols:', df.shape[1])
# Out:
# No. of Rows and Cols (96453, 12)
# No. of Rows: 96453
# No. of Rows: 96453
# No. of Cols: 12
# No. of Cols: 12

# %%
# Values of the specified cloumns
df['Humidity']
# Out:
# 0        0.89
# 1        0.86
# 2        0.89
# 3        0.83
# 4        0.83
#          ...
# 96448    0.43
# 96449    0.48
# 96450    0.56
# 96451    0.60
# 96452    0.61
# Name: Humidity, Length: 96453, dtype: float64

# %%
df[['Humidity', 'Wind Speed (km/h)']]
# Out:
#        Humidity  Wind Speed (km/h)
# 0          0.89            14.1197
# 1          0.86            14.2646
# 2          0.89             3.9284
# 3          0.83            14.1036
# 4          0.83            11.0446
# ...         ...                ...
# 96448      0.43            10.9963
# 96449      0.48            10.0947
# 96450      0.56             8.9838
# 96451      0.60            10.5294
# 96452      0.61             5.8765
#
# [96453 rows x 2 columns]

# %%
# Slicing
# iloc[rows, cols]
# iloc[:, :] # all the rows and all the cols.
# iloc[0:5, :] # rows from 0 to 4 and all the cols.
# iloc[0:5, 0:1] # rows from o to 4 and cols 0 to 1.
# iloc[:, :-1] # all the rows, and all the cols except last column.
# iloc[:, -1] # all the rows, and last column only.

# %%
# Show record from index 10 to 20 and the values of first 3 columns.
df.iloc[10:21, 0:3]
# Out:
#                    Formatted Date        Summary Precip Type
# 10  2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain
# 11  2006-04-01 11:00:00.000 +0200  Partly Cloudy        rain
# 12  2006-04-01 12:00:00.000 +0200  Partly Cloudy        rain
# 13  2006-04-01 13:00:00.000 +0200  Partly Cloudy        rain
# 14  2006-04-01 14:00:00.000 +0200  Partly Cloudy        rain
# 15  2006-04-01 15:00:00.000 +0200  Partly Cloudy        rain
# 16  2006-04-01 16:00:00.000 +0200  Partly Cloudy        rain
# 17  2006-04-01 17:00:00.000 +0200  Mostly Cloudy        rain
# 18  2006-04-01 18:00:00.000 +0200  Mostly Cloudy        rain
# 19  2006-04-01 19:00:00.000 +0200  Mostly Cloudy        rain
# 20  2006-04-01 20:00:00.000 +0200  Mostly Cloudy        rain

# %%
# loc[indexno.] show the row index.
df.loc[10]
# Out:
# Formatted Date                  2006-04-01 10:00:00.000 +0200
# Summary                                         Partly Cloudy
# Precip Type                                              rain
# Temperature (C)                                     16.016667
# Apparent Temperature (C)                            16.016667
# Humidity                                                 0.67
# Wind Speed (km/h)                                     17.5651
# Wind Bearing (degrees)                                  290.0
# Visibility (km)                                       11.2056
# Loud Cover                                                0.0
# Pressure (millibars)                                  1017.42
# Daily Summary               Partly cloudy throughout the day.
# Name: 10, dtype: object

# %%
# Filtering
# show the records where df['Precip Type'] is rain.
df[df['Precip Type'] == 'rain']
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df[['Formatted Date',	'Summary',	'Precip Type',	'Temperature (C)',	'Apparent Temperature (C)']][df['Precip Type'] == 'rain']
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)
# 0             9.472222                  7.388889
# 1             9.355556                  7.227778
# ...

# %%
#['Precip Type'] == 'rain'], [Temperature (C) >9, <15]
df[['Formatted Date',	'Summary',	'Precip Type',	'Temperature (C)',	'Apparent Temperature (C)']][(df['Precip Type'] == 'rain') & ((df['Temperature (C)'] > 9)  & (df['Temperature (C)'] < 15))]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 5      2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain
# 8      2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain
# ...                              ...            ...         ...
# 96362  2016-09-06 05:00:00.000 +0200  Partly Cloudy        rain
# 96363  2016-09-06 06:00:00.000 +0200  Mostly Cloudy        rain
# 96364  2016-09-06 07:00:00.000 +0200  Mostly Cloudy        rain
# 96365  2016-09-06 08:00:00.000 +0200  Mostly Cloudy        rain
# 96435  2016-09-09 06:00:00.000 +0200          Clear        rain
#
#        Temperature (C)  Apparent Temperature (C)
# 0             9.472222                  7.388889
# 1             9.355556                  7.227778
# ...

# %%
df[['Formatted Date',	'Summary',	'Precip Type',	'Temperature (C)',	'Apparent Temperature (C)']][(df['Precip Type'] == 'rain') | (df['Precip Type'] == 'snow')]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)
# 0             9.472222                  7.388889
# 1             9.355556                  7.227778
# ...

# %%
df[['Formatted Date',	'Summary',	'Precip Type',	'Temperature (C)',	'Apparent Temperature (C)']][df['Precip Type'].isin(['rain', 'snow'])]
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)
# 0             9.472222                  7.388889
# 1             9.355556                  7.227778
# ...

# %%
# mathmatical function
df['Humidity'].min()
# Out:
# 0.0

# %%
df['Humidity'].max()
# Out:
# 1.0

# %%
df['Humidity'].mean()
# Out:
# 0.7348989663359355

# %%
df['Humidity'].median()
# Out:
# 0.78

# %%
df['Humidity'].std()
# Out:
# 0.1954727390672154

# %%
# null values
df.isnull()
# Out:
#        Formatted Date  Summary  Precip Type  Temperature (C)  \
# 0               False    False        False            False
# 1               False    False        False            False
# 2               False    False        False            False
# 3               False    False        False            False
# 4               False    False        False            False
# ...               ...      ...          ...              ...
# 96448           False    False        False            False
# 96449           False    False        False            False
# 96450           False    False        False            False
# 96451           False    False        False            False
# 96452           False    False        False            False
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                         False     False              False
# 1                         False     False              False
# ...

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
# Get all the column names
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')
